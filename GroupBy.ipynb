# %%
# Import Dependencies
import pandas as pd
import os

# %%
# Create a reference the CSV file desired
csv_path = os.path.join("Resources", "ufoSightings.csv")

# Read the CSV into a Pandas DataFrame
ufo_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
ufo_df.head()
# Out:
# C:\Users\jeff\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
# Remove the rows with missing data
clean_ufo_df = ufo_df.dropna(how="any")
clean_ufo_df.count()
# Out:
# datetime                66516
# city                    66516
# state                   66516
# country                 66516
# shape                   66516
# duration (seconds)      66516
# duration (hours/min)    66516
# comments                66516
# date posted             66516
# latitude                66516
# longitude               66516
# dtype: int64

# %%
# Converting the "duration (seconds)" column's values to numeric
clean_ufo_df["duration (seconds)"] = pd.to_numeric(clean_ufo_df["duration (seconds)"])
# Out:
# C:\Users\jeff\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Filter the data so that only those sightings in the US are in a DataFrame
usa_ufo_df = clean_ufo_df.loc[clean_ufo_df["country"] == "us",:]

usa_ufo_df.head()
# Out:
#            datetime        city state country     shape  duration (seconds)  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700.0
# 3  10/10/1956 21:00        edna    tx      us    circle                20.0
# 4  10/10/1960 20:00     kaneohe    hi      us     light               900.0
# 5  10/10/1961 19:00     bristol    tn      us    sphere               300.0
# 7  10/10/1965 23:45     norwalk    ct      us      disk              1200.0
#
#   duration (hours/min)                                           comments  \
# 0           45 minutes  This event took place in early fall around 194...
# 3             1/2 hour  My older brother and twin sister were leaving ...
# 4           15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5            5 minutes  My father is now 89 my brother 52 the girl wit...
# 7           20 minutes  A bright orange color changing to reddish colo...
#
#   date posted    latitude  longitude
# 0   4/27/2004  29.8830556  -97.941111
# 3   1/17/2004  28.9783333  -96.645833
# 4   1/22/2004  21.4180556 -157.803611
# 5   4/27/2007      36.595  -82.188889
# 7   10/2/1999     41.1175  -73.408333

# %%
# Count how many sightings have occured within each state
state_counts = usa_ufo_df["state"].value_counts()
state_counts.head()
# Out:
# ca    8683
# fl    3754
# wa    3707
# tx    3398
# ny    2915
# Name: state, dtype: int64

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_usa_df = usa_ufo_df.groupby(['state'], sort = True)

# The object returned is a "GroupBy" object and cannot be viewed normally...
# print(grouped_usa_df) <--This may not work
grouped_usa_df.count()

# In order to be visualized, a data function must be used...
grouped_usa_df.min()
# Out:
#               datetime                                      city country  \
# state
# ak       1/1/2004 0:00                                      adak      us
# al      1/1/1972 20:00                                adamsville      us
# ar      1/1/1965 20:00                                 alexander      us
# az      1/1/1966 17:00                                    aguila      us
# ca      1/1/1944 12:00                                    acampo      us
# co      1/1/1975 20:00                                   aguilar      us
# ct      1/1/2009 19:00                           amston (hebron)      us
# dc     1/29/2012 19:20                                georgetown      us
# de       1/1/2007 0:00                                      bear      us
# fl       1/1/1962 8:00                                   alachua      us
# ga      1/1/1975 19:00                                   acworth      us
# hi       1/1/1998 4:00                                      aiea      us
# ia      1/1/1965 20:00                                     adair      us
# id      1/1/1978 13:00                            american falls      us
# il      1/1/1965 17:00                                  abingdon      us
# in      1/1/1961 13:00                                     acton      us
# ks       1/1/1997 7:00                                   abilene      us
# ky       1/1/1986 3:00                                adairville      us
# la      1/1/1968 21:00                                 abbeville      us
# ma      1/1/1980 23:30                                  abington      us
# md      1/1/1968 23:00                                  aberdeen      us
# me      1/1/2001 19:00                                     acton      us
# mi      1/1/1970 12:00                                      acme      us
# mn      1/10/2006 4:00                                       ada      us
# mo       1/1/1970 2:00                                    agency      us
# ms       1/1/2013 0:02                                  ackerman      us
# mt      1/1/1963 22:00                                  alberton      us
# nc      1/1/1982 20:00                                  aberdeen      us
# nd       1/1/1997 7:00                                    amenia      us
# ne       1/1/2003 2:00                                 ainsworth      us
# nh       1/1/2013 0:15                                    albany      us
# nj       1/1/1968 0:00                                   absecon      us
# nm      1/1/2006 17:00                                alamogordo      us
# nv      1/1/2002 22:30                                     alamo      us
# ny       1/1/1975 3:00                                    accord      us
# oh       1/1/2000 3:00                                  aberdeen      us
# ok       1/1/1981 1:00                                       ada      us
# or      1/1/2000 17:00                                    albany      us
# pa       1/1/1998 1:42                                  abington      us
# pr      1/10/1999 1:00  arecibo (just s of&#44 rural central pr)      us
# ri     1/14/2013 17:00                                   ashaway      us
# sc      1/1/1995 15:00                                 abbeville      us
# sd     1/12/2013 21:00                                  aberdeen      us
# tn      1/1/1973 23:30                                     adams      us
# tx      1/1/1957 21:00                                   abilene      us
# ut       1/1/2011 0:07                                    alpine      us
# va      1/1/2007 21:30                                  abingdon      us
# vt       1/1/2012 0:15                                 arlington      us
# wa      1/1/1972 16:00                                  aberdeen      us
# wi       1/1/2003 0:30                                     adams      us
# wv       1/1/1956 5:30                                     alloy      us
# wy     1/11/2001 21:50                                    alcova      us
#
#           shape  duration (seconds)   duration (hours/min)  \
# state
# ak     changing                1.00                 .5 hrs
# al     changing                0.50           0.5  seconds
# ar     changing                0.20          00:15 seconds
# az     changing                0.10              # mintues
# ca     changing                0.10   20 minutes (ongoing)
# co      changed                0.50              +/- 2min.
# ct     changing                1.00             .5 - 1 min
# dc     changing                4.00             10 minutes
# de     changing                1.00                   0:45
# fl     changing                1.00                +1 hour
# ga     changing                0.10          +/- 5 minutes
# hi     changing                1.00                    0.4
# ia     changing                0.50                   0:07
# id     changing                0.30             +/- 5 min.
# il     changing                0.01           +/- 1 minute
# in     changing                0.50          +/-15 minutes
# ks     changing                1.00                   0:45
# ky     changing                1.00           -6 hours cst
# la     changing                1.00               .30 min.
# ma     changing                0.50               0.5 hour
# md     changing                0.30            .30 seconds
# me     changing                0.40           +/- 10 mins.
# mi     changing                0.50              (minutes)
# mn     changing                0.33          .5-.75 minute
# mo     changing                0.50               0.5 sec.
# ms     changing                1.00                 03 min
# mt     changing                1.00                0:10:00
# nc     changing                0.05            +/- 1minute
# nd     changing                1.00                   0:45
# ne     changing                1.00             05 minutes
# nh     changing                0.50             0.5 second
# nj     changing                0.50             +/- 4 mins
# nm     changing                0.50             -5 minutes
# nv     changing                0.45              +- 5 mins
# ny     changing                0.05         +/- 4  minutes
# oh     changing                0.50               .5 hours
# ok     changing                0.50                 .5 sec
# or     changing                0.01               .08 sec.
# pa     changing                0.50              .5 second
# pr        cigar                2.00               0:01min.
# ri     changing                0.50                   0:05
# sc     changing                0.50                 -3 min
# sd     changing                1.50          1 1/2 seconds
# tn     changing                1.00           0.05 minutes
# tx     changing                0.50                +30 min
# ut     changing                0.50            0.5 seconds
# va     changing                1.00                0:00:15
# vt     changing                1.00               +/-5 min
# wa     changing                0.01           +/- 2minutes
# wi     changing                1.00                   0:01
# wv     changing                1.00                0:02:50
# wy     changing                1.00                   0:45
#
#                                                 comments date posted  \
# state
# ak           &#39Rocket boosters&#39  over North Pole AK   1/10/2009
# al     &quot;I don&#39t know what the hell that is&quot;   1/10/2009
# ar     &quot;V-Shaped&quot; object passing over Lowel...   1/10/2009
# az                                                #NAME?   1/10/2009
# ca      a bright red light  coming straight fom the t...   1/10/2009
# co     &quot;String of Pearls&quot;  White&#44 cloud ...   1/10/2009
# ct     &quot;Black Triangle&quot; spotted in CT back ...   1/10/2009
# dc     3 objects in 15 minutes&#44 2 balls of light m...   1/12/2012
# de                                   &quot;Stealth&quot;   1/10/2009
# fl      a ufo was orbiting mars&#33&#33&#33  ((NUFORC...   1/10/2009
# ga                                &quot;false dawn&quot;   1/10/2009
# hi     09/04/94&#44 Ewa Beach HI&#44 Unidentified Spa...   1/10/2009
# ia     &#9;&#9;  &#9;I was outside smoking a cigarett...   1/10/2009
# id     &quot;Star&quot; brightend in shy&#44 then slo...   1/10/2014
# il     &#39star bright white&#39 teardrop object stre...   1/10/2009
# in      ((HOAX??))  4th  of July ufo and a image of a...   1/10/2009
# ks     &#39X&#39 shaped&#44 fairly slow moving&#44 qu...   1/10/2009
# ky     &quot;Baton-shaped&quot; object moving end-ove...   1/10/2009
# la     ((HOAX??))  A UFO flew right over my house in ...   1/10/2009
# ma                                                Circle   1/10/2009
# md      I noticed that the stars didn&#8217;t seem ri...   1/10/2009
# me     ((NUFORC Note:  Missile launch at 2055 hrs (ED...   1/10/2009
# mi     &#9;I saw four white lights&#44 three in a row...   1/10/2009
# mn     &quot;Chrome&quot; ball over the cliffs of St....   1/10/2009
# mo     ((HOAX))  I was standing on my porch&#44 smoki...   1/10/2009
# ms     &quot;Satellite&quot; stops&#44 flases and dis...   1/10/2009
# mt      I looked forward and noticed in the upper rig...   1/10/2009
# nc        &quot;Moon Lander&quot; Shaped UFO Stormy day.   1/10/2009
# nd     10-25-06  Circle  North Dakota  5 minutes  Shi...   1/10/2009
# ne     &quot;Burning&quot; flying object passes at le...   1/10/2009
# nh     ((HOAX??))  A loud vibrating sound and a low f...   1/10/2009
# nj     &#9;I was at Union Beach at about 7:00 p.m. in...   1/10/2009
# nm      ((NUFORC Note:  Helium-filled heliostat.  PD)...   1/10/2009
# nv     &quot;Shooting Star&quot; Slows&#44 Turns&#44 ...   1/10/2009
# ny      I saw a brilliant white light moving.  ((NUFO...   1/10/2009
# oh      thought it was a star but then it moved becam...   1/10/2009
# ok     &#39&#39ON ICE PROJECT&#39&#39 - UNDERGROUND C...   1/10/2009
# or     &#9;I was walking from my house&#44 the local ...   1/10/2009
# pa      3/12/10Viewed a comet like object very bright...   1/10/2009
# pr     At around 8:00 pm on an Apirl evening NASA was...   1/11/2002
# ri     ((HOAX))  flying saucer speeds by overhead whi...   1/10/2009
# sc     $ bright lights over Atlantic Ocean flying in ...   1/10/2009
# sd     &quot; A bright light was seen in the sky and ...   1/10/2009
# tn     &quot;My friend and I seen this pure white bal...   1/10/2009
# tx     &quot;Black Triangle&quot; UFO with 3 White Li...   1/10/2009
# ut          &quot;Clear &#44 Jellyfish&quot; type object   1/10/2009
# va     &quot;Bat-wing&quot; aircraft swiftly crosses ...   1/10/2009
# vt     ((HOAX??))  200 foot black triangle with alter...   1/10/2009
# wa      A RED Light was seen over the Highland Park a...   1/10/2009
# wi      ((NUFORC Note:  Date is invalid.  PD))Triangl...   1/10/2009
# wv     ((HOAX??))  The objects were floating above a ...   1/10/2009
# wy     &quot;V&quot; shaped craft moving north to sou...   1/10/2009
#
#        longitude
# state
# ak    -176.658056
# al     -88.342222
# ar     -94.540278
# az    -114.781389
# ca    -124.262778
# co    -108.804167
# ct     -73.628889
# dc     -77.062778
# de     -75.750000
# fl     -87.427500
# ga     -85.531111
# hi    -159.715000
# ia     -96.605556
# id    -117.016667
# il     -91.409722
# in     -87.895000
# ks    -101.889722
# ky     -89.186111
# la     -93.972778
# ma     -73.416667
# md     -79.406944
# me     -70.981111
# mi     -90.170833
# mn     -97.024167
# mo     -95.516667
# ms     -91.403056
# mt    -115.888611
# nc     -84.034722
# nd    -103.925833
# ne    -103.666667
# nh     -72.486944
# nj     -75.516944
# nm    -109.033333
# nv    -119.987778
# ny     -79.732778
# oh     -84.820000
# ok    -102.962778
# or    -124.496111
# pa     -80.496944
# pr     -67.250278
# ri     -71.827778
# sc     -83.096667
# sd    -103.858889
# tn     -90.048889
# tx    -106.486389
# ut    -114.036667
# va     -83.082222
# vt     -73.340833
# wa    -124.623611
# wi     -92.801944
# wv     -82.578333
# wy    -110.962500

# %%
# Since "duration (seconds)" was converted to a numeric time, it can now be summed up per state
state_duration = grouped_usa_df["duration (seconds)"].sum()
state_duration.head()
# Out:
# state
# ak     1455863.00
# al      900453.50
# ar    66986144.50
# az    15453494.60
# ca    24865571.47
# Name: duration (seconds), dtype: float64

# %%
# Creating a new DataFrame using both duration and count
state_summary_table = pd.DataFrame({"Number of Sightings":state_counts,
                                   "Total Visit Time":state_duration})
state_summary_table.head()
# Out:
#     Number of Sightings  Total Visit Time
# ak                  311        1455863.00
# al                  629         900453.50
# ar                  578       66986144.50
# az                 2362       15453494.60
# ca                 8683       24865571.47

# %%
# It is also possible to group a DataFrame by multiple columns
# This returns an object with multiple indexes, however, which can be harder to deal with
grouped_international_data = clean_ufo_df.groupby(['country','state'])

# Converting a GroupBy object into a DataFrame
international_duration = pd.DataFrame(grouped_international_data["duration (seconds)"].sum())
international_duration.head(10)
